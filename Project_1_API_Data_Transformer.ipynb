# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti-ai-generalist-portfolio/AIHorizon/blob/main/Project_1_API_Data_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project 1: API Data Transformer
#
# Build a Python program that reads JSON customer records, filters them, transforms fields and exports a clean JSON/CSV report.
#
# PROJECT: Input messy customer JSON → normalize names/emails/companies → remove duplicates → output clean_customers.csv and summary.json. Publish notebook + README.

# %%
# !pip install validators
# Out:
# Collecting validators
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 927.1 kB/s eta 0:00:00
# Installing collected packages: validators
# Successfully installed validators-0.35.0

# %%
#customer_id 958
#first_name Amitie
#last_name Antoniottii
#email aantoniottiiql@kickstarter.com
#gender Female
#phonenumber 227-251-5671
#addressline1 17th Floor
#city Pescara
#state Abruzzi
#pincode 65129


import json
import validators
import email_validator

try:
  with open("CustomerData.json","r") as myFile:
    customerDataDump = json.load(myFile)

  for x in customerDataDump:
    for key,value in x.items():
      if (key == "email"):
        if (validators.email(value)):
            print ("Valid Email id ", value)
        else:
          print ("Invalid Email id ", value)
except FileNotFoundError:
  print ("File not found")
except json.JSONDecodeError:
  print ("Invalid JSON")
# Out:
# Valid Email id  ekivelhan0@soundcloud.com
# Invalid Email id  dgergher1digg.com
# Valid Email id  sstroband2@cyberchimps.com
# Valid Email id  uwainscot3@bing.com
# Valid Email id  vcranmer4@nationalgeographic.com
# Valid Email id  swellings5@comcast.net
# Valid Email id  tmcgiveen6@phpbb.com
# Valid Email id  nbardell7@prlog.org
# Valid Email id  jboylan8@google.co.uk
# Valid Email id  ugladeche9@dailymotion.com
# Valid Email id  esallengera@photobucket.com
# Valid Email id  rgiggieb@diigo.com
# Valid Email id  jpointc@macromedia.com
# Valid Email id  pbessetd@economist.com
# Valid Email id  cgrasere@blogspot.com
# Valid Email id  pthulbornf@stumbleupon.com
# Valid Email id  gellikerg@nba.com
# Valid Email id  lhearsumh@reddit.com
# Valid Email id  jpedroli@yale.edu
# Valid Email id  hdansiej@shinystat.com
# Valid Email id  kbrittlesk@oakley.com
# Valid Email id  mstokesl@bluehost.com
# Valid Email id  cmctavym@irs.gov
# Valid Email id  rriattn@flickr.com
# Valid Email id  mtuppenyo@ezinearticles.com
# Valid Email id  lgrimditchp@dropbox.com
# Valid Email id  cathelstanq@dyndns.org
# Valid Email id  scowansr@cyberchimps.com
# Valid Email id  ebrushfields@quantcast.com
# Valid Email id  tcremert@furl.net
# Valid Email id  csprowellu@vkontakte.ru
# Valid Email id  mdimmackv@dmoz.org
# Valid Email id  apeterkenw@yolasite.com
# Valid Email id  phaggarx@imgur.com
# Valid Email id  ktoughy@ca.gov
# Valid Email id  scocherz@goodreads.com
# Valid Email id  mridsdell10@forbes.com
# Valid Email id  mbonanno11@reuters.com
# Valid Email id  hbutterick12@aol.com
# Valid Email id  mdelatour13@psu.edu
# Valid Email id  byakobowitch14@zdnet.com
# Valid Email id  clawfull15@tinypic.com
# Valid Email id  wbanham16@netlog.com
# Valid Email id  wboreland17@pen.io
# Valid Email id  pbriddle18@smugmug.com
# Valid Email id  haglione19@hao123.com
# Valid Email id  jgrangier1a@diigo.com
# Valid Email id  pranscome1b@gizmodo.com
# Valid Email id  kmcdermottrow1c@tripadvisor.com
# Valid Email id  tgoretti1d@wunderground.com
# Valid Email id  wbrimfield1e@uol.com.br
# Valid Email id  eibbitson1f@lycos.com
# Valid Email id  cgerhold1g@arstechnica.com
# Valid Email id  afalkous1h@rambler.ru
# Valid Email id  rwhithorn1i@storify.com
# Valid Email id  ndeldello1j@livejournal.com
# Valid Email id  lpym1k@jigsy.com
# Valid Email id  screed1l@amazon.com
# Valid Email id  akoba1m@nyu.edu
# Valid Email id  rshenley1n@virginia.edu
# Valid Email id  tdrynan1o@npr.org
# Valid Email id  jnorker1p@mail.ru
# Valid Email id  hodoohaine1q@rambler.ru
# Valid Email id  scahill1r@irs.gov
# Valid Email id  hshubotham1s@lycos.com
# Valid Email id  hkobelt1t@phoca.cz
# Valid Email id  etue1u@ox.ac.uk
# Valid Email id  cfulun1v@webeden.co.uk
# Valid Email id  mallflatt1w@techcrunch.com
# Valid Email id  elefebre1x@so-net.ne.jp
# Valid Email id  dspur1y@storify.com
# Valid Email id  agriston1z@ox.ac.uk
# Valid Email id  rmanson20@zdnet.com
# Valid Email id  tmcentegart21@purevolume.com
# Valid Email id  lgetcliffe22@blogspot.com
# Valid Email id  cjefford23@sphinn.com
# Valid Email id  hwestmerland24@wix.com
# Valid Email id  tduguid25@jiathis.com
# Valid Email id  mtosh26@oracle.com
# Valid Email id  hking27@multiply.com
# Valid Email id  hhumby28@howstuffworks.com
# Valid Email id  cbeckett29@buzzfeed.com
# Valid Email id  mlots2a@bloglines.com
# Valid Email id  cgayle2b@wix.com
# Valid Email id  npountain2c@wunderground.com
# Valid Email id  lbanes2d@youtu.be
# Valid Email id  mhalleday2e@mayoclinic.com
# Valid Email id  ggrono2f@skyrock.com
# Valid Email id  bholson2g@unblog.fr
# Valid Email id  kolivet2h@about.com
# Valid Email id  mbeecraft2i@economist.com
# Valid Email id  aashlin2j@walmart.com
# Valid Email id  nkenningham2k@vimeo.com
# Valid Email id  eflott2l@acquirethisname.com
# Valid Email id  syoungs2m@ihg.com
# Valid Email id  smowling2n@europa.eu
# Valid Email id  ebickford2o@comcast.net
# Valid Email id  dbrandt2p@alibaba.com
# Valid Email id  jlainton2q@nasa.gov
# Valid Email id  lrentcome2r@over-blog.com
# Valid Email id  shatley2s@storify.com
# Valid Email id  sblouet2t@gmpg.org
# Valid Email id  pblaszczyk2u@wufoo.com
# Valid Email id  ecrofts2v@vinaora.com
# Valid Email id  ndaines2w@lycos.com
# Valid Email id  mmathe2x@people.com.cn
# Valid Email id  mbiesterfeld2y@hc360.com
# Valid Email id  gbreinlein2z@multiply.com
# Valid Email id  zellesmere30@toplist.cz
# Valid Email id  hbrobyn31@google.nl
# Valid Email id  mgorham32@time.com
# Valid Email id  hnoore33@aol.com
# Valid Email id  abeseke34@washingtonpost.com
# Valid Email id  vrestieaux35@nih.gov
# Valid Email id  cteese36@amazon.com
# Valid Email id  pkulis37@nhs.uk
# Valid Email id  ascougall38@fotki.com
# Valid Email id  egiacopazzi39@t-online.de
# Valid Email id  troomes3a@hhs.gov
# Valid Email id  bgreenall3b@loc.gov
# Valid Email id  breeks3c@bbc.co.uk
# Valid Email id  nvinecombe3d@amazonaws.com
# Valid Email id  rdury3e@craigslist.org
# Valid Email id  fblaase3f@slate.com
# Valid Email id  hfautly3g@chronoengine.com
# Valid Email id  ubloyes3h@wikimedia.org
# Valid Email id  tpace3i@sourceforge.net
# Valid Email id  aibbotson3j@php.net
# Valid Email id  jesselen3k@slideshare.net
# Valid Email id  nadrian3l@delicious.com
# Valid Email id  jfearn3m@linkedin.com
# Valid Email id  dgoodlet3n@youtube.com
# Valid Email id  tpetroulis3o@360.cn
# Valid Email id  ilethby3p@deliciousdays.com
# Valid Email id  cprodrick3q@dailymotion.com
# Valid Email id  hdowner3r@sciencedirect.com
# Valid Email id  hrickersey3s@technorati.com
# Valid Email id  lshaw3t@unc.edu
# Valid Email id  lwaye3u@uiuc.edu
# Valid Email id  cgerard3v@unesco.org
# Valid Email id  mcastello3w@unblog.fr
# Valid Email id  nlamcken3x@aol.com
# Valid Email id  akepp3y@princeton.edu
# Valid Email id  kgreeno3z@tinyurl.com
# Valid Email id  mthackham40@devhub.com
# Valid Email id  jcastanho41@networkadvertising.org
# Valid Email id  cgrimwad42@abc.net.au
# Valid Email id  wjoffe43@tripod.com
# Valid Email id  bjillis44@studiopress.com
# Valid Email id  rvictor45@cargocollective.com
# Valid Email id  sanear46@timesonline.co.uk
# Valid Email id  bfowley47@msn.com
# Valid Email id  hblunsom48@hc360.com
# Valid Email id  mfearney49@ed.gov
# Valid Email id  bdallewater4a@oaic.gov.au
# Valid Email id  adickin4b@tiny.cc
# Valid Email id  mdigweed4c@theglobeandmail.com
# Valid Email id  mdikles4d@usa.gov
# Valid Email id  kgellately4e@pbs.org
# Valid Email id  cfeilden4f@edublogs.org
# Valid Email id  wlemarquis4g@printfriendly.com
# Valid Email id  ascaysbrook4h@samsung.com
# Valid Email id  dkabsch4i@liveinternet.ru
# Valid Email id  dgostling4j@wix.com
# Valid Email id  rride4k@a8.net
# Valid Email id  lmcfall4l@ebay.com
# Valid Email id  wserle4m@timesonline.co.uk
# Valid Email id  batger4n@mediafire.com
# Valid Email id  scavee4o@sogou.com
# Valid Email id  tsymington4p@netscape.com
# Valid Email id  shyett4q@eepurl.com
# Valid Email id  kradenhurst4r@vinaora.com
# Valid Email id  tinott4s@go.com
# Valid Email id  mloughney4t@arstechnica.com
# Valid Email id  bkinze4u@eepurl.com
# Valid Email id  efacey4v@seattletimes.com
# Valid Email id  edunbleton4w@imdb.com
# Valid Email id  melcocks4x@answers.com
# Valid Email id  mramstead4y@hugedomains.com
# Valid Email id  dconklin4z@dmoz.org
# Valid Email id  apiscot50@webmd.com
# Valid Email id  osancias51@sitemeter.com
# Valid Email id  wbartel52@netscape.com
# Valid Email id  hsloper53@uiuc.edu
# Valid Email id  ahallad54@huffingtonpost.com
# Valid Email id  gwyrall55@toplist.cz
# Valid Email id  kprenty56@nytimes.com
# Valid Email id  mpatek57@youtu.be
# Valid Email id  mdowdeswell58@vkontakte.ru
# Valid Email id  ostreatfeild59@desdev.cn
# Valid Email id  nphilippet5a@ucoz.ru
# Valid Email id  vhoneywood5b@washingtonpost.com
# Valid Email id  abickerdike5c@umn.edu
# Valid Email id  gchat5d@guardian.co.uk
# Valid Email id  twingeat5e@phoca.cz
# Valid Email id  mgerrets5f@wikia.com
# Valid Email id  ksouster5g@zimbio.com
# Valid Email id  bstockford5h@mozilla.org
# Valid Email id  brosbotham5i@whitehouse.gov
# Valid Email id  redrich5j@sakura.ne.jp
# Valid Email id  mhastewell5k@home.pl
# Valid Email id  thavill5l@toplist.cz
# Valid Email id  nfawdrie5m@t.co
# Valid Email id  ereston5n@google.fr
# Valid Email id  jbockings5o@ucoz.com
# Valid Email id  eyele5p@jimdo.com
# Valid Email id  rcomini5q@time.com
# Valid Email id  phaydon5r@pcworld.com
# Valid Email id  lhapgood5s@ucoz.ru
# Valid Email id  amagovern5t@vkontakte.ru
# Valid Email id  ltarburn5u@google.ru
# Valid Email id  jwoolager5v@boston.com
# Valid Email id  kbolf5w@foxnews.com
# Valid Email id  abarensky5x@va.gov
# Valid Email id  spennetta5y@deliciousdays.com
# Valid Email id  iratcliffe5z@rakuten.co.jp
# Valid Email id  iteffrey60@walmart.com
# Valid Email id  adonise61@google.co.uk
# Valid Email id  ramiss62@php.net
# Valid Email id  tjeremaes63@ocn.ne.jp
# Valid Email id  sraffles64@omniture.com
# Valid Email id  bgreenin65@sitemeter.com
# Valid Email id  mcrenage66@mlb.com
# Valid Email id  dkevern67@china.com.cn
# Valid Email id  rpolkinhorn68@netscape.com
# Valid Email id  ebyart69@nymag.com
# Valid Email id  dmclenaghan6a@soundcloud.com
# Valid Email id  rreidshaw6b@ed.gov
# Valid Email id  srosenblatt6c@odnoklassniki.ru
# Valid Email id  teasterfield6d@ft.com
# Valid Email id  srigler6e@hugedomains.com
# Valid Email id  bkeywood6f@blogspot.com
# Valid Email id  battenborrow6g@reuters.com
# Valid Email id  icastro6h@ustream.tv
# Valid Email id  stinson6i@about.com
# Valid Email id  mroller6j@ted.com
# Valid Email id  usedge6k@ifeng.com
# Valid Email id  cbaldery6l@twitter.com
# Valid Email id  crochford6m@pbs.org
# Valid Email id  cjoist6n@accuweather.com
# Valid Email id  djahnig6o@4shared.com
# Valid Email id  nbecks6p@va.gov
# Valid Email id  clohden6q@usatoday.com
# Valid Email id  sdracksford6r@wikia.com
# Valid Email id  bfomichkin6s@google.cn
# Valid Email id  tpercy6t@businessinsider.com
# Valid Email id  henser6u@apple.com
# Valid Email id  tkibbye6v@unesco.org
# Valid Email id  cwroath6w@spotify.com
# Valid Email id  bbrahams6x@gov.uk
# Valid Email id  ebrugman6y@vk.com
# Valid Email id  khammell6z@sourceforge.net
# Valid Email id  mcannaway70@google.co.jp
# Valid Email id  cbrugsma71@state.tx.us
# Valid Email id  lleyes72@google.com.br
# Valid Email id  bfeehan73@nytimes.com
# Valid Email id  dbownes74@harvard.edu
# Valid Email id  ogarlee75@webnode.com
# Valid Email id  kmoralas76@uiuc.edu
# Valid Email id  smcgannon77@moonfruit.com
# Valid Email id  emcneilley78@slashdot.org
# Valid Email id  acollecott79@reuters.com
# Valid Email id  bmarkova7a@purevolume.com
# Valid Email id  rambrosio7b@nymag.com
# Valid Email id  blowndsbrough7c@csmonitor.com
# Valid Email id  ehabbon7d@epa.gov
# Valid Email id  lcurnokk7e@wix.com
# Valid Email id  mmackneis7f@indiegogo.com
# Valid Email id  llighton7g@sitemeter.com
# Valid Email id  kwainer7h@nytimes.com
# Valid Email id  edabinett7i@cloudflare.com
# Valid Email id  bjentet7j@linkedin.com
# Valid Email id  qcrosfield7k@lulu.com
# Valid Email id  mvasentsov7l@yellowbook.com
# Valid Email id  obraemer7m@mashable.com
# Valid Email id  molenchenko7n@friendfeed.com
# Valid Email id  mdobbison7o@gizmodo.com
# Valid Email id  pgatherer7p@europa.eu
# Valid Email id  sskryne7q@google.ca
# Valid Email id  twhitticks7r@nps.gov
# Valid Email id  akeysel7s@nationalgeographic.com
# Valid Email id  wpogue7t@cpanel.net
# Valid Email id  rdeclerq7u@diigo.com
# Valid Email id  pcundict7v@hud.gov
# Valid Email id  cgillice7w@wikia.com
# Valid Email id  okeoghan7x@addtoany.com
# Valid Email id  ssmaleman7y@alexa.com
# Valid Email id  mhatcher7z@webnode.com
# Valid Email id  smoodie80@reference.com
# Valid Email id  eklambt81@dedecms.com
# Valid Email id  mskillitt82@ucoz.ru
# Valid Email id  rpegram83@about.me
# Valid Email id  khuggen84@meetup.com
# Valid Email id  rhebron85@slideshare.net
# Valid Email id  ahubery86@oakley.com
# Valid Email id  amckeowon87@studiopress.com
# Valid Email id  mattenbrough88@bravesites.com
# Valid Email id  zjerdein89@si.edu
# Valid Email id  bjent8a@fastcompany.com
# Valid Email id  mbrittan8b@over-blog.com
# Valid Email id  tadenot8c@addtoany.com
# Valid Email id  pswainger8d@go.com
# Valid Email id  lspellessy8e@gmpg.org
# Valid Email id  gmaudlin8f@parallels.com
# Valid Email id  fgoseling8g@twitter.com
# Valid Email id  ngabbitus8h@myspace.com
# Valid Email id  gposton8i@samsung.com
# Valid Email id  jmathis8j@blogs.com
# Valid Email id  agrinaway8k@godaddy.com
# Valid Email id  lbleasdale8l@upenn.edu
# Valid Email id  cnye8m@linkedin.com
# Valid Email id  bmacgahey8n@berkeley.edu
# Valid Email id  eflaunier8o@clickbank.net
# Valid Email id  keagell8p@irs.gov
# Valid Email id  pmacak8q@ed.gov
# Valid Email id  rdarker8r@skyrock.com
# Valid Email id  tboc8s@taobao.com
# Valid Email id  ijirka8t@godaddy.com
# Valid Email id  ecorrie8u@shop-pro.jp
# Valid Email id  ksmalles8v@sphinn.com
# Valid Email id  qgallichan8w@independent.co.uk
# Valid Email id  cislip8x@people.com.cn
# Valid Email id  vjansky8y@ycombinator.com
# Valid Email id  ashillitto8z@istockphoto.com
# Valid Email id  lrosbrough90@is.gd
# Valid Email id  ogingles91@prweb.com
# Valid Email id  dmottershead92@last.fm
# Valid Email id  bsymes93@businessinsider.com
# Valid Email id  kdaal94@yahoo.com
# Valid Email id  lglowach95@sitemeter.com
# Valid Email id  mchetham96@go.com
# Valid Email id  mpeckett97@un.org
# Valid Email id  kshimony98@npr.org
# Valid Email id  abartalin99@umn.edu
# Valid Email id  lbacher9a@theatlantic.com
# Valid Email id  ssugars9b@bigcartel.com
# Valid Email id  sdrivers9c@mtv.com
# Valid Email id  gcheney9d@surveymonkey.com
# Valid Email id  opawson9e@auda.org.au
# Valid Email id  ftzar9f@unblog.fr
# Valid Email id  hchateau9g@ox.ac.uk
# Valid Email id  hboggas9h@myspace.com
# Valid Email id  ncudihy9i@smugmug.com
# Valid Email id  fkerford9j@gnu.org
# Valid Email id  mstapleton9k@thetimes.co.uk
# Valid Email id  idessent9l@zdnet.com
# Valid Email id  ssoares9m@addthis.com
# Valid Email id  fginger9n@live.com
# Valid Email id  ccurnow9o@hostgator.com
# Valid Email id  clind9p@sohu.com
# Valid Email id  cbellows9q@techcrunch.com
# Valid Email id  ecorpe9r@biglobe.ne.jp
# Valid Email id  alevey9s@china.com.cn
# Valid Email id  rtrenear9t@nationalgeographic.com
# Valid Email id  acollabine9u@slashdot.org
# Valid Email id  giacobini9v@rakuten.co.jp
# Valid Email id  jayrs9w@ameblo.jp
# Valid Email id  wacklands9x@rakuten.co.jp
# Valid Email id  mshakespeare9y@archive.org
# Valid Email id  sllewhellin9z@wisc.edu
# Valid Email id  jpriuma0@naver.com
# Valid Email id  estreatfielda1@posterous.com
# Valid Email id  rkliementa2@webs.com
# Valid Email id  jlacroixa3@mapquest.com
# Valid Email id  ctimbsa4@51.la
# Valid Email id  phuea5@tripod.com
# Valid Email id  mbauma6@hexun.com
# Valid Email id  esonscheina7@yahoo.com
# Valid Email id  evalentina8@shop-pro.jp
# Valid Email id  wmenezesa9@nsw.gov.au
# Valid Email id  aabraminoaa@de.vu
# Valid Email id  cbanburyab@macromedia.com
# Valid Email id  btegellerac@pagesperso-orange.fr
# Valid Email id  sanderbruggead@desdev.cn
# Valid Email id  nphettisae@parallels.com
# Valid Email id  tbrownsettaf@usgs.gov
# Valid Email id  istillwellag@noaa.gov
# Valid Email id  cduddyah@fc2.com
# Valid Email id  mtathacottai@tamu.edu
# Valid Email id  gdraceyaj@netvibes.com
# Valid Email id  itowellak@edublogs.org
# Valid Email id  ejosipovical@tumblr.com
# Valid Email id  fburrellam@europa.eu
# Valid Email id  aknivettan@army.mil
# Valid Email id  gmenearao@dropbox.com
# Valid Email id  wmewittap@noaa.gov
# Valid Email id  cnorwellaq@china.com.cn
# Valid Email id  mcumminear@yolasite.com
# Valid Email id  gscopynas@wikipedia.org
# Valid Email id  fmccarleat@sbwire.com
# Valid Email id  asilversmidau@zimbio.com
# Valid Email id  mworthyav@istockphoto.com
# Valid Email id  evacheraw@51.la
# Valid Email id  abugbirdax@symantec.com
# Valid Email id  sscothornay@marriott.com
# Valid Email id  rdehoogeaz@soup.io
# Valid Email id  ebaylayb0@lycos.com
# Valid Email id  aaldrittb1@nsw.gov.au
# Valid Email id  dfippeb2@omniture.com
# Valid Email id  agockelerb3@qq.com
# Valid Email id  jburnallb4@who.int
# Valid Email id  jhullotb5@usatoday.com
# Valid Email id  dscottesmoorb6@infoseek.co.jp
# Valid Email id  dallikerb7@51.la
# Valid Email id  mmaguireb8@netscape.com
# Valid Email id  dbraidonb9@utexas.edu
# Valid Email id  egreenroadba@de.vu
# Valid Email id  bpozzibb@timesonline.co.uk
# Valid Email id  wheelbc@cisco.com
# Valid Email id  lcantrillbd@shutterfly.com
# Valid Email id  fsalkeldbe@cafepress.com
# Valid Email id  succellibf@mtv.com
# Valid Email id  npetticrowbg@diigo.com
# Valid Email id  bmckewbh@army.mil
# Valid Email id  rwattbi@harvard.edu
# Valid Email id  sklemencicbj@ask.com
# Valid Email id  ddabelbk@soundcloud.com
# Valid Email id  hmacelholmbl@live.com
# Valid Email id  jlingnerbm@php.net
# Valid Email id  vphizackerlybn@engadget.com
# Valid Email id  rmatyushkinbo@fema.gov
# Valid Email id  mpenkethmanbp@dell.com
# Valid Email id  cgrogorbq@europa.eu
# Valid Email id  apennettibr@paypal.com
# Valid Email id  egilbertsonbs@adobe.com
# Valid Email id  jmcparlinbt@xing.com
# Valid Email id  ewoolenbu@archive.org
# Valid Email id  gstarsmorebv@cmu.edu
# Valid Email id  landreassonbw@reference.com
# Valid Email id  cthewbx@discuz.net
# Valid Email id  esawreyby@unblog.fr
# Valid Email id  mrizonbz@i2i.jp
# Valid Email id  edyballc0@hp.com
# Valid Email id  csitchc1@businessweek.com
# Valid Email id  mharrissonc2@sakura.ne.jp
# Valid Email id  tpetrelluzzic3@gov.uk
# Valid Email id  mwoodruffc4@ycombinator.com
# Valid Email id  vbearfootc5@tumblr.com
# Valid Email id  thaszardc6@sbwire.com
# Valid Email id  csessionsc7@cdc.gov
# Valid Email id  chelliarc8@themeforest.net
# Valid Email id  lgajownikc9@tripod.com
# Valid Email id  rjoanca@amazonaws.com
# Valid Email id  pleahcb@rediff.com
# Valid Email id  bfairncc@123-reg.co.uk
# Valid Email id  rmcpaikecd@phpbb.com
# Valid Email id  lpugsleyce@rediff.com
# Valid Email id  brheamcf@ustream.tv
# Valid Email id  narnoldscg@constantcontact.com
# Valid Email id  cwoodrooffech@ibm.com
# Valid Email id  lkyntonci@bravesites.com
# Valid Email id  pcressycj@squarespace.com
# Valid Email id  cgogginsck@buzzfeed.com
# Valid Email id  ccanedocl@amazon.com
# Valid Email id  avassecm@tinyurl.com
# Valid Email id  mbulloughcn@domainmarket.com
# Valid Email id  cblucherco@mit.edu
# Valid Email id  gmartincp@ocn.ne.jp
# Valid Email id  pmatkincq@marketwatch.com
# Valid Email id  fbertolincr@hud.gov
# Valid Email id  hrunnaclescs@gravatar.com
# Valid Email id  wbertomierct@answers.com
# Valid Email id  bschneidarcu@prnewswire.com
# Valid Email id  msurplicecv@wikipedia.org
# Valid Email id  dzannelicw@prweb.com
# Valid Email id  dbalselliecx@yolasite.com
# Valid Email id  galveycy@blogspot.com
# Valid Email id  akernescz@timesonline.co.uk
# Valid Email id  shanscomd0@berkeley.edu
# Valid Email id  sgatteridged1@qq.com
# Valid Email id  dmerdewd2@about.me
# Valid Email id  agascard3@nbcnews.com
# Valid Email id  skleined4@whitehouse.gov
# Valid Email id  cdooherd5@cbc.ca
# Valid Email id  pepslyd6@mac.com
# Valid Email id  bbealtond7@comcast.net
# Valid Email id  mferreresd8@engadget.com
# Valid Email id  dtremathackd9@indiegogo.com
# Valid Email id  aellingworthda@canalblog.com
# Valid Email id  abramhamdb@histats.com
# Valid Email id  avenningdc@edublogs.org
# Valid Email id  wmccowendd@arstechnica.com
# Valid Email id  tmanwaringde@wikia.com
# Valid Email id  tpitkindf@umich.edu
# Valid Email id  sclucasdg@state.gov
# Valid Email id  jsalmendh@usnews.com
# Valid Email id  nheersmadi@noaa.gov
# Valid Email id  seagerdj@wordpress.org
# Valid Email id  erenedk@netlog.com
# Valid Email id  eglitherowdl@tamu.edu
# Valid Email id  ntixierdm@51.la
# Valid Email id  ashirleydn@geocities.jp
# Valid Email id  segertondo@imageshack.us
# Valid Email id  eseamansdp@accuweather.com
# Valid Email id  dmiddlemassdq@ovh.net
# Valid Email id  sorwindr@berkeley.edu
# Valid Email id  cstandidgeds@weather.com
# Valid Email id  ibembridgedt@gravatar.com
# Valid Email id  aksandradu@last.fm
# Valid Email id  tdellortodv@comcast.net
# Valid Email id  jwinspeardw@mashable.com
# Valid Email id  bmeadmoredx@nydailynews.com
# Valid Email id  fcornuaudy@angelfire.com
# Valid Email id  lmerguedz@mayoclinic.com
# Valid Email id  cgeraghtye0@tripod.com
# Valid Email id  hgerine1@soup.io
# Valid Email id  higlesiase2@topsy.com
# Valid Email id  bcallendere3@tiny.cc
# Valid Email id  fwhitloee4@moonfruit.com
# Valid Email id  idenisete5@usnews.com
# Valid Email id  ajorge6@fda.gov
# Valid Email id  dmccrackene7@jalbum.net
# Valid Email id  kscutcheone8@about.me
# Valid Email id  tcockrane9@deliciousdays.com
# Valid Email id  gstreatea@addtoany.com
# Valid Email id  mridgedelleb@google.co.jp
# Valid Email id  ttubblesec@unblog.fr
# Valid Email id  fdoonicaned@networkadvertising.org
# Valid Email id  rmathesee@toplist.cz
# Valid Email id  harmfirldef@webmd.com
# Valid Email id  athaineg@over-blog.com
# Valid Email id  sstuttmaneh@quantcast.com
# Valid Email id  cslyneei@addthis.com
# Valid Email id  tjackwaysej@4shared.com
# Valid Email id  lhugginek@hp.com
# Valid Email id  hgameel@irs.gov
# Valid Email id  ssheerinem@goodreads.com
# Valid Email id  taddlestoneen@imdb.com
# Valid Email id  jswindelleo@cornell.edu
# Valid Email id  doakeep@yelp.com
# Valid Email id  sroycrofteq@blogspot.com
# Valid Email id  mbeacher@intel.com
# Valid Email id  aprenees@accuweather.com
# Valid Email id  mkuhneet@elegantthemes.com
# Valid Email id  lmargeryeu@1und1.de
# Valid Email id  tgauldev@blogs.com
# Valid Email id  ldowardew@feedburner.com
# Valid Email id  jcorkerex@census.gov
# Valid Email id  grathjeney@va.gov
# Valid Email id  dscandwrightez@live.com
# Valid Email id  aholdworthf0@wordpress.org
# Valid Email id  sacarsonf1@webs.com
# Valid Email id  ihobbingf2@so-net.ne.jp
# Valid Email id  fpetzoldf3@posterous.com
# Valid Email id  bmerrymanf4@phoca.cz
# Valid Email id  nchalonerf5@e-recht24.de
# Valid Email id  arisdallf6@archive.org
# Valid Email id  erougierf7@examiner.com
# Valid Email id  tchastelf8@indiatimes.com
# Valid Email id  rharvettf9@sitemeter.com
# Valid Email id  dboggishfa@privacy.gov.au
# Valid Email id  wcozensfb@networkadvertising.org
# Valid Email id  szanuttifc@nih.gov
# Valid Email id  jbilofskyfd@noaa.gov
# Valid Email id  bflorisfe@ucsd.edu
# Valid Email id  cbattyllff@oakley.com
# Valid Email id  fsantellofg@squarespace.com
# Valid Email id  bprovestfh@wisc.edu
# Valid Email id  amalthousefi@usgs.gov
# Valid Email id  yheggefj@ucla.edu
# Valid Email id  eadnamsfk@printfriendly.com
# Valid Email id  mfuentesfl@histats.com
# Valid Email id  aharmstonefm@squarespace.com
# Valid Email id  mdrippfn@netscape.com
# Valid Email id  staintonfo@so-net.ne.jp
# Valid Email id  gwetwoodfp@biblegateway.com
# Valid Email id  znosworthyfq@sphinn.com
# Valid Email id  khelkinfr@tiny.cc
# Valid Email id  fachrameevfs@reddit.com
# Valid Email id  jfacherft@craigslist.org
# Valid Email id  dsmelliefu@constantcontact.com
# Valid Email id  tstermanfv@wikimedia.org
# Valid Email id  sboocockfw@qq.com
# Valid Email id  jhorderfx@webmd.com
# Valid Email id  kphizacleafy@shutterfly.com
# Valid Email id  bdeighanfz@skype.com
# Valid Email id  tdivesg0@phoca.cz
# Valid Email id  sprateng1@nsw.gov.au
# Valid Email id  kfassong2@reference.com
# Valid Email id  cschulkinsg3@yellowbook.com
# Valid Email id  jgilloolyg4@elegantthemes.com
# Valid Email id  tsimkissg5@go.com
# Valid Email id  lgongg6@bandcamp.com
# Valid Email id  sduffilg7@slate.com
# Valid Email id  bgreedingg8@icio.us
# Valid Email id  hcastagnarog9@storify.com
# Valid Email id  mdarmodyga@lycos.com
# Valid Email id  cbegginigb@reference.com
# Valid Email id  fgahangc@multiply.com
# Valid Email id  fsuntergd@utexas.edu
# Valid Email id  hwaterhousege@nba.com
# Valid Email id  mfallowfieldgf@hud.gov
# Valid Email id  cbathagg@npr.org
# Valid Email id  dpantonegh@prlog.org
# Valid Email id  tbaylygi@nasa.gov
# Valid Email id  avauxgj@icio.us
# Valid Email id  ldabellgk@tripadvisor.com
# Valid Email id  nlalondegl@jiathis.com
# Valid Email id  cgutierrezgm@ehow.com
# Valid Email id  kdodgshungn@over-blog.com
# Valid Email id  rdreschlergo@paypal.com
# Valid Email id  ctevelovgp@boston.com
# Valid Email id  rkamiyamagq@sakura.ne.jp
# Valid Email id  hcaheygr@lycos.com
# Valid Email id  hballsgs@ocn.ne.jp
# Valid Email id  amcallestergt@blogtalkradio.com
# Valid Email id  swheldongu@berkeley.edu
# Valid Email id  klayhegv@ning.com
# Valid Email id  nworlockgw@tumblr.com
# Valid Email id  lrammellgx@fda.gov
# Valid Email id  srangeleygy@cisco.com
# Valid Email id  smuskettgz@twitter.com
# Valid Email id  srobroseh0@t-online.de
# Valid Email id  halldreadh1@jigsy.com
# Valid Email id  mfarnillh2@latimes.com
# Valid Email id  ssteinh3@usda.gov
# Valid Email id  abaeldeh4@storify.com
# Valid Email id  afitzhenryh5@wufoo.com
# Valid Email id  byandellh6@bloglines.com
# Valid Email id  skegleyh7@yahoo.co.jp
# Valid Email id  npaslowh8@cmu.edu
# Valid Email id  wpuddefooth9@zdnet.com
# Valid Email id  pledsterha@reddit.com
# Valid Email id  kivaninhb@ucsd.edu
# Valid Email id  hdeveyhc@sciencedaily.com
# Valid Email id  hpolinhd@jimdo.com
# Valid Email id  lridewoodhe@cisco.com
# Valid Email id  atavernorhf@quantcast.com
# Valid Email id  afennerhg@google.nl
# Valid Email id  esparsholthh@alexa.com
# Valid Email id  amckillophi@jigsy.com
# Valid Email id  vbeateyhj@gravatar.com
# Valid Email id  rpoorhk@businesswire.com
# Valid Email id  ctyreshl@godaddy.com
# Valid Email id  cvanyardhm@toplist.cz
# Valid Email id  rlandmanhn@google.nl
# Valid Email id  cthoringtonho@t-online.de
# Valid Email id  rverrallhp@stanford.edu
# Valid Email id  alackeyehq@theguardian.com
# Valid Email id  ebontinehr@nhs.uk
# Valid Email id  cbucknerhs@skype.com
# Valid Email id  hbuddockht@fema.gov
# Valid Email id  rjojichu@netlog.com
# Valid Email id  npavlikhv@thetimes.co.uk
# Valid Email id  mullrichhw@dmoz.org
# Valid Email id  ccorderhx@github.io
# Valid Email id  rgeratthy@theatlantic.com
# Valid Email id  ipeterffyhz@time.com
# Valid Email id  cpryni0@sbwire.com
# Valid Email id  abuckhami1@macromedia.com
# Valid Email id  alowndsboroughi2@oaic.gov.au
# Valid Email id  kmeahi3@topsy.com
# Valid Email id  bthowi4@slate.com
# Valid Email id  acantoi5@typepad.com
# Valid Email id  jbrownsworthi6@seattletimes.com
# Valid Email id  gjessei7@parallels.com
# Valid Email id  jcroixi8@gov.uk
# Valid Email id  rjeayesi9@wordpress.org
# Valid Email id  uwilmania@technorati.com
# Valid Email id  smahaffeyib@dailymotion.com
# Valid Email id  idissic@ca.gov
# Valid Email id  awentid@webeden.co.uk
# Valid Email id  aformieie@earthlink.net
# Valid Email id  lquibellif@microsoft.com
# Valid Email id  egobolosig@ebay.com
# Valid Email id  bphantih@wp.com
# Valid Email id  roakshottii@bloglines.com
# Valid Email id  squarlessij@hud.gov
# Valid Email id  dpettigreeik@aol.com
# Valid Email id  tdanzeyil@surveymonkey.com
# Valid Email id  jcarlettiim@g.co
# Valid Email id  rharrodin@un.org
# Valid Email id  cstandallio@army.mil
# Valid Email id  aamorineip@bluehost.com
# Valid Email id  elightollersiq@pcworld.com
# Valid Email id  telwoodir@epa.gov
# Valid Email id  tcolebornis@disqus.com
# Valid Email id  ccandlinit@blogspot.com
# Valid Email id  bmatousekiu@baidu.com
# Valid Email id  mjaumeiv@chicagotribune.com
# Valid Email id  jmcaviyiw@ucla.edu
# Valid Email id  psackettix@youtu.be
# Valid Email id  mfearnsiy@canalblog.com
# Valid Email id  bknokiz@google.es
# Valid Email id  slegricej0@va.gov
# Valid Email id  hhoggettsj1@topsy.com
# Valid Email id  dkinchinj2@spiegel.de
# Valid Email id  nshillakerj3@sitemeter.com
# Valid Email id  kgherardescij4@stanford.edu
# Valid Email id  jgaifordj5@google.com
# Valid Email id  hathertonj6@patch.com
# Valid Email id  eshanahanj7@hexun.com
# Valid Email id  eaingerj8@gravatar.com
# Valid Email id  rbehanj9@addthis.com
# Valid Email id  cwhylieja@wiley.com
# Valid Email id  sedwardsjb@etsy.com
# Valid Email id  lbottjc@ow.ly
# Valid Email id  nburganejd@yahoo.com
# Valid Email id  lminorje@microsoft.com
# Valid Email id  eaartsenjf@dmoz.org
# Valid Email id  dchifneyjg@state.gov
# Valid Email id  lprettejohnsjh@cisco.com
# Valid Email id  ksonierji@flavors.me
# Valid Email id  aprowtingjj@abc.net.au
# Valid Email id  lleamyjk@freewebs.com
# Valid Email id  bnollethjl@newsvine.com
# Valid Email id  yboydonjm@seattletimes.com
# Valid Email id  gbrimilcombejn@wsj.com
# Valid Email id  dashingtonjo@fda.gov
# Valid Email id  cwhiskerjp@barnesandnoble.com
# Valid Email id  phawsonjq@addtoany.com
# Valid Email id  ncameratijr@arstechnica.com
# Valid Email id  fgrzeszczykjs@skype.com
# Valid Email id  jkeeganjt@china.com.cn
# Valid Email id  bbarckeju@netlog.com
# Valid Email id  aschoffeljv@wired.com
# Valid Email id  lcicculinijw@imdb.com
# Valid Email id  esheajx@odnoklassniki.ru
# Valid Email id  wgorryjy@typepad.com
# Valid Email id  aserrelljz@cocolog-nifty.com
# Valid Email id  ecookmank0@salon.com
# Valid Email id  dchazettek1@liveinternet.ru
# Valid Email id  gdaberk2@vimeo.com
# Valid Email id  hclearsk3@clickbank.net
# Valid Email id  agoblek4@google.co.uk
# Valid Email id  vdickonsk5@discovery.com
# Valid Email id  hbucktharpk6@live.com
# Valid Email id  gandreask7@vimeo.com
# Valid Email id  celnerk8@bigcartel.com
# Valid Email id  jflahivek9@myspace.com
# Valid Email id  marendtka@illinois.edu
# Valid Email id  dybarrakb@china.com.cn
# Valid Email id  myesipovkc@feedburner.com
# Valid Email id  hgrogankd@flickr.com
# Valid Email id  anowerke@github.io
# Valid Email id  kjentkf@networkadvertising.org
# Valid Email id  rakamkg@wunderground.com
# Valid Email id  mnisslekh@indiatimes.com
# Valid Email id  gholthamki@cnn.com
# Valid Email id  iqueenboroughkj@salon.com
# Valid Email id  enernkk@dyndns.org
# Valid Email id  tstanningkl@state.gov
# Valid Email id  cmcauslankm@sphinn.com
# Valid Email id  eswiffankn@networksolutions.com
# Valid Email id  ogoldisko@wix.com
# Valid Email id  rleaskkp@cargocollective.com
# Valid Email id  mtolandkq@furl.net
# Valid Email id  mwalbridgekr@cbslocal.com
# Valid Email id  rlanktreeks@loc.gov
# Valid Email id  rverrellkt@g.co
# Valid Email id  kcolesku@naver.com
# Valid Email id  lfryattkv@google.es
# Valid Email id  gmecchikw@businessweek.com
# Valid Email id  mtukesbykx@amazon.co.uk
# Valid Email id  arowenky@hud.gov
# Valid Email id  sashfieldkz@samsung.com
# Valid Email id  cjanusl0@go.com
# Valid Email id  wsoeirol1@engadget.com
# Valid Email id  nbythelll2@exblog.jp
# Valid Email id  gwasselll3@addtoany.com
# Valid Email id  bsherbornl4@vk.com
# Valid Email id  gdicarlol5@mediafire.com
# Valid Email id  jwhiffinl6@nymag.com
# Valid Email id  alangcasterl7@goo.ne.jp
# Valid Email id  cgrasnerl8@rakuten.co.jp
# Valid Email id  kpaquetl9@mapquest.com
# Valid Email id  jyirrellla@telegraph.co.uk
# Valid Email id  rbruckmannlb@yellowbook.com
# Valid Email id  jzanetellolc@over-blog.com
# Valid Email id  kyearnsld@intel.com
# Valid Email id  aloadesle@guardian.co.uk
# Valid Email id  nbryninglf@soup.io
# Valid Email id  mpallinlg@dropbox.com
# Valid Email id  ufranckelh@spiegel.de
# Valid Email id  tmayli@fda.gov
# Valid Email id  dfaulkeslj@stumbleupon.com
# Valid Email id  eaustinslk@twitpic.com
# Valid Email id  rzannutoll@amazonaws.com
# Valid Email id  alapthornelm@bravesites.com
# Valid Email id  mfanninln@skype.com
# Valid Email id  emclellanlo@uiuc.edu
# Valid Email id  nnurnylp@china.com.cn
# Valid Email id  ntunnahlq@indiatimes.com
# Valid Email id  ssimmelllr@wordpress.org
# Valid Email id  elaugierls@hhs.gov
# Valid Email id  omerrylt@printfriendly.com
# Valid Email id  dkuschalu@free.fr
# Valid Email id  rmerceylv@drupal.org
# Valid Email id  acaronlw@nifty.com
# Valid Email id  hlarrattlx@unblog.fr
# Valid Email id  ejeanenetly@mozilla.org
# Valid Email id  cdykaslz@infoseek.co.jp
# Valid Email id  adawdrym0@feedburner.com
# Valid Email id  rnasebym1@hud.gov
# Valid Email id  bivaninm2@google.com.au
# Valid Email id  cmoldm3@loc.gov
# Valid Email id  cgoldsburym4@pinterest.com
# Valid Email id  athickettm5@typepad.com
# Valid Email id  lginmanm6@goo.gl
# Valid Email id  rdafterm7@cloudflare.com
# Valid Email id  iglendinningm8@wikia.com
# Valid Email id  dabramm9@gmpg.org
# Valid Email id  ycrickmoorma@google.co.uk
# Valid Email id  hkytemb@wp.com
# Valid Email id  mbarrusmc@cdbaby.com
# Valid Email id  ljoinsonmd@dyndns.org
# Valid Email id  csherrumme@bandcamp.com
# Valid Email id  musmarmf@friendfeed.com
# Valid Email id  ljerremsmg@phpbb.com
# Valid Email id  icollerdmh@wordpress.org
# Valid Email id  gballemi@weibo.com
# Valid Email id  spieraccimj@hp.com
# Valid Email id  etrenbaymk@mozilla.com
# Valid Email id  grevenml@issuu.com
# Valid Email id  gdmtrovicmm@sohu.com
# Valid Email id  dmintrimmn@lulu.com
# Valid Email id  tcoursormo@soup.io
# Valid Email id  rsouthernsmp@pinterest.com
# Valid Email id  twemyssmq@bloglines.com
# Valid Email id  dkohnenmr@sitemeter.com
# Valid Email id  zaslumms@opera.com
# Valid Email id  gluckmt@ftc.gov
# Valid Email id  nmeasommu@qq.com
# Valid Email id  geadmeadmv@ibm.com
# Valid Email id  dspinasmw@zimbio.com
# Valid Email id  mdalliwatrmx@stumbleupon.com
# Valid Email id  kwinghammy@ow.ly
# Valid Email id  aitzikmz@vimeo.com
# Valid Email id  iatackn0@jugem.jp
# Valid Email id  jgowann1@example.com
# Valid Email id  ttofflern2@cargocollective.com
# Valid Email id  cbrissen3@vkontakte.ru
# Valid Email id  asliden4@shop-pro.jp
# Valid Email id  jrosingdalln5@theguardian.com
# Valid Email id  ogarfathn6@goo.gl
# Valid Email id  aglayshern7@dedecms.com
# Valid Email id  hlaffann8@hugedomains.com
# Valid Email id  mgrubeyn9@spotify.com
# Valid Email id  tjansensna@github.io
# Valid Email id  alambertznb@ezinearticles.com
# Valid Email id  echalcraftnc@bizjournals.com
# Valid Email id  bdunnicond@sakura.ne.jp
# Valid Email id  fyokelne@xing.com
# Valid Email id  aseviernf@macromedia.com
# Valid Email id  rwolfordng@hao123.com
# Valid Email id  pputnamnh@github.com
# Valid Email id  jshirilni@mashable.com
# Valid Email id  lwhiteheadnj@discuz.net
# Valid Email id  agarvillnk@icq.com
# Valid Email id  kwestmorenl@live.com
# Valid Email id  edronsfieldnm@privacy.gov.au
# Valid Email id  mespinelnn@newyorker.com
# Valid Email id  ksyfaxno@netscape.com
# Valid Email id  agajowniknp@csmonitor.com
# Valid Email id  jellettnq@reddit.com
# Valid Email id  lpirisnr@washingtonpost.com
# Valid Email id  cdopplerns@hibu.com
# Valid Email id  chanburynt@webmd.com
# Valid Email id  stembridgenu@flavors.me
# Valid Email id  umereweathernv@va.gov
# Valid Email id  rbuttfieldnw@4shared.com
# Valid Email id  pnanglenx@guardian.co.uk
# Valid Email id  msaffinny@cam.ac.uk
# Valid Email id  rbedownz@hhs.gov
# Valid Email id  amattielloo0@sohu.com
# Valid Email id  ecornhillo1@multiply.com
# Valid Email id  pmaccomiskeyo2@miitbeian.gov.cn
# Valid Email id  mpoyleo3@symantec.com
# Valid Email id  vathero4@usda.gov
# Valid Email id  ngarwello5@google.pl
# Valid Email id  agerltso6@google.ru
# Valid Email id  myashaevo7@unesco.org
# Valid Email id  daizlewoodo8@hao123.com
# Valid Email id  cmaclennano9@merriam-webster.com
# Valid Email id  hlightewoodoa@amazon.co.jp
# Valid Email id  adavauxob@bloomberg.com
# Valid Email id  mgorleroc@un.org
# Valid Email id  bmattecotod@elpais.com
# Valid Email id  ileborgneoe@phoca.cz
# Valid Email id  mlosseljongof@linkedin.com
# Valid Email id  tdummettog@unicef.org
# Valid Email id  radkinoh@over-blog.com
# Valid Email id  mbagniukoi@craigslist.org
# Valid Email id  mcoytesoj@networkadvertising.org
# Valid Email id  fbrelsfordok@msn.com
# Valid Email id  fwreightol@dyndns.org
# Valid Email id  ggouleyom@phoca.cz
# Valid Email id  apenleyon@hp.com
# Valid Email id  ijellardoo@ehow.com
# Valid Email id  dnolletop@webeden.co.uk
# Valid Email id  poscullyoq@symantec.com
# Valid Email id  gnassieor@sciencedirect.com
# Valid Email id  amcinteeos@techcrunch.com
# Valid Email id  lpizzieot@blogger.com
# Valid Email id  nveillardou@businesswire.com
# Valid Email id  mtinklerov@techcrunch.com
# Valid Email id  swordingtonow@tuttocitta.it
# Valid Email id  jhumblesox@studiopress.com
# Valid Email id  kfarrearsoy@va.gov
# Valid Email id  rsavinsoz@mac.com
# Valid Email id  vfoxleyp0@etsy.com
# Valid Email id  bsciussciettop1@cpanel.net
# Valid Email id  emithamp2@blinklist.com
# Valid Email id  rsurplicep3@behance.net
# Valid Email id  tfaulknerp4@creativecommons.org
# Valid Email id  jmarkelp5@t-online.de
# Valid Email id  dberkap6@goo.gl
# Valid Email id  jpikhnop7@cbslocal.com
# Valid Email id  bkorejsp8@tamu.edu
# Valid Email id  gpranglep9@oakley.com
# Valid Email id  lcattlemullpa@weather.com
# Valid Email id  skickpb@biblegateway.com
# Valid Email id  gcornnerpc@bloomberg.com
# Valid Email id  hturbatpd@nhs.uk
# Valid Email id  tdommettpe@fastcompany.com
# Valid Email id  dzecchipf@census.gov
# Valid Email id  mfilonierepg@globo.com
# Valid Email id  hjiraph@myspace.com
# Valid Email id  ftedahlpi@moonfruit.com
# Valid Email id  wfaustpj@mail.ru
# Valid Email id  ejennenspk@economist.com
# Valid Email id  saberhartpl@com.com
# Valid Email id  mfonquerniepm@naver.com
# Valid Email id  sstenbridgepn@chron.com
# Valid Email id  sjoninpo@joomla.org
# Valid Email id  cgummorypp@hibu.com
# Valid Email id  jmckennanpq@people.com.cn
# Valid Email id  rcressarpr@mlb.com
# Valid Email id  awiddecombeps@devhub.com
# Valid Email id  gcottispt@gnu.org
# Valid Email id  oeslemontpu@time.com
# Valid Email id  bbohlpv@cpanel.net
# Valid Email id  iminnispw@shop-pro.jp
# Valid Email id  igabrielpx@gizmodo.com
# Valid Email id  ehurcombepy@netvibes.com
# Valid Email id  dkesonpz@ezinearticles.com
# Valid Email id  graymondq0@xinhuanet.com
# Valid Email id  ejeryq1@boston.com
# Valid Email id  kleonq2@hao123.com
# Valid Email id  hpinchq3@simplemachines.org
# Valid Email id  sketchq4@cmu.edu
# Valid Email id  lbarksq5@artisteer.com
# Valid Email id  jkegginq6@naver.com
# Valid Email id  rgoobleq7@barnesandnoble.com
# Valid Email id  kdewberryq8@gizmodo.com
# Valid Email id  bmacmakinq9@archive.org
# Valid Email id  ngilfetherqa@berkeley.edu
# Valid Email id  gtellenbrookqb@last.fm
# Valid Email id  ebolzenqc@drupal.org
# Valid Email id  sroadsqd@feedburner.com
# Valid Email id  sdanskineqe@yahoo.com
# Valid Email id  trubegaqf@usda.gov
# Valid Email id  wongeqg@slate.com
# Valid Email id  rbellasqh@blinklist.com
# Valid Email id  mastallqi@webmd.com
# Valid Email id  hbaldamqj@sourceforge.net
# Valid Email id  mshewqk@youtube.com
# Valid Email id  aantoniottiiql@kickstarter.com
# Valid Email id  jscoatesqm@guardian.co.uk
# Valid Email id  fgynniqn@about.com
# Valid Email id  dtrobeyqo@storify.com
# Valid Email id  gmouldsqp@sciencedirect.com
# Valid Email id  tedgecombeqq@creativecommons.org
# Valid Email id  kabbatiniqr@theguardian.com
# Valid Email id  rmattiazziqs@hao123.com
# Valid Email id  ggertqt@mashable.com
# Valid Email id  udriscollqu@oracle.com
# Valid Email id  hwarnesqv@histats.com
# Valid Email id  pmarchenkoqw@shutterfly.com
# Valid Email id  oianniniqx@ft.com
# Valid Email id  nraiseqy@nasa.gov
# Valid Email id  cmacinerneyqz@facebook.com
# Valid Email id  phamertonr0@apple.com
# Valid Email id  ggumlyr1@umich.edu
# Valid Email id  khawthorner2@ebay.com
# Valid Email id  wpetrasr3@1688.com
# Valid Email id  mmcfeatr4@mit.edu
# Valid Email id  ugennerichr5@jimdo.com
# Valid Email id  apearsallr6@comsenz.com
# Valid Email id  wloosr7@bandcamp.com
# Valid Email id  bheddyr8@senate.gov
# Valid Email id  hwaddoupsr9@msu.edu
# Valid Email id  lbonehamra@biblegateway.com
# Valid Email id  egrevilerb@zimbio.com
# Valid Email id  dmaundrellrc@discovery.com
# Valid Email id  fbouldenrd@tripadvisor.com
# Valid Email id  cevennettre@privacy.gov.au
# Valid Email id  rdellorf@stanford.edu
# Valid Email id  knewlandsrg@washingtonpost.com
# Valid Email id  asheeranrh@bandcamp.com
# Valid Email id  dmclartyri@rakuten.co.jp
# Valid Email id  jfindingrj@xinhuanet.com
# Valid Email id  hgebuhrrk@goo.ne.jp
# Valid Email id  hrubanenkorl@dailymotion.com
# Valid Email id  agibbonsonrm@joomla.org
# Valid Email id  rguittrn@bravesites.com
# Valid Email id  chalesworthro@bandcamp.com
# Valid Email id  othunderchiefrp@blog.com
# Valid Email id  bpiscopellorq@issuu.com
# Valid Email id  jmesserrr@blogger.com
