# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti-ai-generalist-portfolio/artificial-intelligence-horizon.github.io/blob/main/ai_demo_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mydict = {}
mydict['One'] = "This is the first record in my dictionary"
mydict['56'] = "This is my second record in the dictionary"

print (mydict.keys())
print (mydict.values())
print (mydict.get('One'))

myList = [1,2,3,4]
myVal = 0
while (myVal < 10):
  print ("I came in here with myVal", myVal)
  myVal++
else:
  print ("I came in with my Val here in false", myVal)
# Out:
# dict_keys(['One', '56'])
# dict_values(['This is the first record in my dictionary', 'This is my second record in the dictionary'])
# This is the first record in my dictionary
# I came in false
